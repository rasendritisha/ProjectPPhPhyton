# %% [markdown]
# <a href="https://colab.research.google.com/github/rasendritisha/ProjectPPhPhyton/blob/main/ProjectUAS_PPh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Path ke file CSV di Google Drive Anda
file_aset = '/content/drive/My Drive/Tabel-Aset-Tetap.csv'
file_kebijakan = '/content/drive/My Drive/Tabel-Kebijakan-Fiskal.csv'
file_transaksi = '/content/drive/My Drive/Tabel-Transaksi-Keuangan.csv'

# Memuat data dari file CSV
try:
    df_aset = pd.read_csv(file_aset)
    df_kebijakan = pd.read_csv(file_kebijakan)
    df_transaksi = pd.read_csv(file_transaksi)
    print("File CSV berhasil dimuat.")
except FileNotFoundError:
    print("Pastikan file CSV berada di direktori 'My Drive' di Google Drive Anda.")
    exit()

# --- Eksplorasi Data ---

print("\n--- Analisis Data Tabel-Aset-Tetap.csv ---")
print(df_aset.info())
print(df_aset.describe())
print("Nilai yang hilang:\n", df_aset.isnull().sum())

print("\n--- Analisis Data Tabel-Kebijakan-Fiskal.csv ---")
print(df_kebijakan.info())
print(df_kebijakan.describe())
print("Nilai yang hilang:\n", df_kebijakan.isnull().sum())

print("\n--- Analisis Data Tabel-Transaksi-Keuangan.csv ---")
print(df_transaksi.info())
print(df_transaksi.describe())
print("Nilai yang hilang:\n", df_transaksi.isnull().sum())

# --- Visualisasi Data (Contoh) ---

# Contoh visualisasi untuk df_aset (asumsikan ada kolom numerik 'Nilai')
if 'Nilai' in df_aset.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df_aset['Nilai'], bins=20, kde=True, color='skyblue')
    plt.title('Distribusi Nilai Aset Tetap')
    plt.xlabel('Nilai')
    plt.ylabel('Frekuensi')
    plt.show()

# Contoh visualisasi untuk df_kebijakan (asumsikan ada kolom kategori 'Tahun' dan kolom numerik 'Anggaran')
if 'Tahun' in df_kebijakan.columns and 'Anggaran' in df_kebijakan.columns:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_kebijakan, x='Tahun', y='Anggaran', marker='o', color='lightcoral')
    plt.title('Tren Anggaran Kebijakan Fiskal per Tahun')
    plt.xlabel('Tahun')
    plt.ylabel('Anggaran')
    plt.grid(True)
    plt.show()

# Contoh visualisasi untuk df_transaksi (asumsikan ada kolom kategori 'Jenis Transaksi' dan kolom numerik 'Jumlah')
if 'Jenis Transaksi' in df_transaksi.columns and 'Jumlah' in df_transaksi.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df_transaksi, x='Jenis Transaksi', y='Jumlah', palette='viridis')
    plt.title('Distribusi Jumlah Transaksi per Jenis')
    plt.xlabel('Jenis Transaksi')
    plt.ylabel('Jumlah')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# --- Analisis Komprehensif (Contoh) ---

# Contoh analisis korelasi antar kolom numerik dalam df_transaksi
if df_transaksi.select_dtypes(include=np.number).shape[1] > 1: # Cek apakah ada lebih dari satu kolom numerik
    print("\n--- Analisis Korelasi dalam Tabel-Transaksi-Keuangan.csv ---")
    correlation_matrix = df_transaksi.select_dtypes(include=np.number).corr()
    print(correlation_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Heatmap Korelasi Tabel-Transaksi-Keuangan.csv')
    plt.show()

# Anda dapat menambahkan analisis lain di sini sesuai dengan kebutuhan Anda
# Misalnya, menggabungkan DataFrame, melakukan analisis time series, dll.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File CSV berhasil dimuat.
#
# --- Analisis Data Tabel-Aset-Tetap.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aset_id          10 non-null     object
#  1   kategori         10 non-null     object
#  2   nilai_perolehan  10 non-null     object
#  3   umur_ekonomis    10 non-null     int64
#  4   metode           10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes
# None
#        umur_ekonomis
# count      10.000000
# mean       13.200000
# std         9.647107
# min         4.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max        30.000000
# Nilai yang hilang:
#  aset_id            0
# kategori           0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import numpy as np # Tambahkan baris ini untuk mengimpor numpy

# Mount Google Drive
drive.mount('/content/drive')

# Path ke file CSV di Google Drive Anda
file_aset = '/content/drive/My Drive/Tabel-Aset-Tetap.csv'
file_kebijakan = '/content/drive/My Drive/Tabel-Kebijakan-Fiskal.csv'
file_transaksi = '/content/drive/My Drive/Tabel-Transaksi-Keuangan.csv'

# Memuat data dari file CSV
try:
    df_aset = pd.read_csv(file_aset)
    df_kebijakan = pd.read_csv(file_kebijakan)
    df_transaksi = pd.read_csv(file_transaksi)
    print("File CSV berhasil dimuat.")
except FileNotFoundError:
    print("Pastikan file CSV berada di direktori 'My Drive' di Google Drive Anda.")
    exit()

# --- Eksplorasi Data ---

print("\n--- Analisis Data Tabel-Aset-Tetap.csv ---")
print(df_aset.info())
print(df_aset.describe())
print("Nilai yang hilang:\n", df_aset.isnull().sum())

print("\n--- Analisis Data Tabel-Kebijakan-Fiskal.csv ---")
print(df_kebijakan.info())
print(df_kebijakan.describe())
print("Nilai yang hilang:\n", df_kebijakan.isnull().sum())

print("\n--- Analisis Data Tabel-Transaksi-Keuangan.csv ---")
print(df_transaksi.info())
print(df_transaksi.describe())
print("Nilai yang hilang:\n", df_transaksi.isnull().sum())

# --- Visualisasi Data (Contoh) ---

# Contoh visualisasi untuk df_aset (asumsikan ada kolom numerik 'Nilai')
if 'Nilai' in df_aset.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df_aset['Nilai'], bins=20, kde=True, color='skyblue')
    plt.title('Distribusi Nilai Aset Tetap')
    plt.xlabel('Nilai')
    plt.ylabel('Frekuensi')
    plt.show()

# Contoh visualisasi untuk df_kebijakan (asumsikan ada kolom kategori 'Tahun' dan kolom numerik 'Anggaran')
if 'Tahun' in df_kebijakan.columns and 'Anggaran' in df_kebijakan.columns:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_kebijakan, x='Tahun', y='Anggaran', marker='o', color='lightcoral')
    plt.title('Tren Anggaran Kebijakan Fiskal per Tahun')
    plt.xlabel('Tahun')
    plt.ylabel('Anggaran')
    plt.grid(True)
    plt.show()

# Contoh visualisasi untuk df_transaksi (asumsikan ada kolom kategori 'Jenis Transaksi' dan kolom numerik 'Jumlah')
if 'Jenis Transaksi' in df_transaksi.columns and 'Jumlah' in df_transaksi.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df_transaksi, x='Jenis Transaksi', y='Jumlah', palette='viridis')
    plt.title('Distribusi Jumlah Transaksi per Jenis')
    plt.xlabel('Jenis Transaksi')
    plt.ylabel('Jumlah')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# --- Analisis Komprehensif (Contoh) ---

# Contoh analisis korelasi antar kolom numerik dalam df_transaksi
if df_transaksi.select_dtypes(include=np.number).shape[1] > 1: # Cek apakah ada lebih dari satu kolom numerik
    print("\n--- Analisis Korelasi dalam Tabel-Transaksi-Keuangan.csv ---")
    correlation_matrix = df_transaksi.select_dtypes(include=np.number).corr()
    print(correlation_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Heatmap Korelasi Tabel-Transaksi-Keuangan.csv')
    plt.show()

# Anda dapat menambahkan analisis lain di sini sesuai dengan kebutuhan Anda
# Misalnya, menggabungkan DataFrame, melakukan analisis time series, dll.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File CSV berhasil dimuat.
#
# --- Analisis Data Tabel-Aset-Tetap.csv ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aset_id          10 non-null     object
#  1   kategori         10 non-null     object
#  2   nilai_perolehan  10 non-null     object
#  3   umur_ekonomis    10 non-null     int64
#  4   metode           10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes
# None
#        umur_ekonomis
# count      10.000000
# mean       13.200000
# std         9.647107
# min         4.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max        30.000000
# Nilai yang hilang:
#  aset_id            0
# kategori           0
# ...

# %%
# --- Eksplorasi Data ---

print("\n--- Analisis Data Tabel-Aset-Tetap.csv ---")
print("Beberapa baris pertama:")
print(df_aset.head()) # Menampilkan 5 baris pertama
print("\nInformasi kolom:")
print(df_aset.info())
print("\nStatistik deskriptif:")
print(df_aset.describe())
print("\nNilai yang hilang:\n", df_aset.isnull().sum())

print("\n--- Analisis Data Tabel-Kebijakan-Fiskal.csv ---")
print("Beberapa baris pertama:")
print(df_kebijakan.head()) # Menampilkan 5 baris pertama
print("\nInformasi kolom:")
print(df_kebijakan.info())
print("\nStatistik deskriptif:")
print(df_kebijakan.describe())
print("\nNilai yang hilang:\n", df_kebijakan.isnull().sum())

print("\n--- Analisis Data Tabel-Transaksi-Keuangan.csv ---")
print("Beberapa baris pertama:")
print(df_transaksi.head()) # Menampilkan 5 baris pertama
print("\nInformasi kolom:")
print(df_transaksi.info())
print("\nStatistik deskriptif:")
print(df_transaksi.describe())
print("\nNilai yang hilang:\n", df_transaksi.isnull().sum())
# Out:
# --- Analisis Data Tabel-Aset-Tetap.csv ---
# Beberapa baris pertama:
#   aset_id   kategori nilai_perolehan  umur_ekonomis         metode
# 0    A001      Mesin        800,000              15    garis lurus
# 1    A002   Bangunan      2,500,000              30  saldo menurun
# 2    A003  Kendaraan        600,000               7    garis lurus
# 3    A004  Peralatan        450,000              10  saldo menurun
# 4    A005   Komputer        300,000               4    garis lurus
#
# Informasi kolom:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aset_id          10 non-null     object
#  1   kategori         10 non-null     object
#  2   nilai_perolehan  10 non-null     object
#  3   umur_ekonomis    10 non-null     int64
#  4   metode           10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Path ke file CSV di Google Drive Anda
file_aset = '/content/drive/My Drive/Tabel-Aset-Tetap.csv'
file_kebijakan = '/content/drive/My Drive/Tabel-Kebijakan-Fiskal.csv'
file_transaksi = '/content/drive/My Drive/Tabel-Transaksi-Keuangan.csv'

# Memuat data dari file CSV
try:
    df_aset = pd.read_csv(file_aset)
    df_kebijakan = pd.read_csv(file_kebijakan)
    df_transaksi = pd.read_csv(file_transaksi)
    print("File CSV berhasil dimuat.")
except FileNotFoundError:
    print("Pastikan file CSV berada di direktori 'My Drive' di Google Drive Anda.")
    exit()

# --- Eksplorasi Data Awal (Sudah ada) ---
print("\n--- Analisis Data Tabel-Aset-Tetap.csv ---")
print("Beberapa baris pertama:")
print(df_aset.head())
print("\nInformasi kolom:")
print(df_aset.info())
print("\nStatistik deskriptif:")
print(df_aset.describe())
print("\nNilai yang hilang:\n", df_aset.isnull().sum())

print("\n--- Analisis Data Tabel-Kebijakan-Fiskal.csv ---")
print("Beberapa baris pertama:")
print(df_kebijakan.head())
print("\nInformasi kolom:")
print(df_kebijakan.info())
print("\nStatistik deskriptif:")
print(df_kebijakan.describe())
print("\nNilai yang hilang:\n", df_kebijakan.isnull().sum())

print("\n--- Analisis Data Tabel-Transaksi-Keuangan.csv ---")
print("Beberapa baris pertama:")
print(df_transaksi.head())
print("\nInformasi kolom:")
print(df_transaksi.info())
print("\nStatistik deskriptif:")
print(df_transaksi.describe())
print("\nNilai yang hilang:\n", df_transaksi.isnull().sum())


# --- Analisis Mendalam per Kolom ---

def analyze_column(df, column_name):
    """Melakukan analisis mendalam pada kolom tertentu."""
    print(f"\n--- Analisis Kolom: {column_name} ---")
    print(f"Tipe data: {df[column_name].dtype}")
    print(f"Jumlah nilai yang hilang: {df[column_name].isnull().sum()}")
    print(f"Jumlah nilai unik: {df[column_name].nunique()}")
    if df[column_name].nunique() < 20: # Tampilkan nilai unik jika tidak terlalu banyak
        print(f"Nilai unik: {df[column_name].unique()}")

    # Jika kolom numerik, tampilkan distribusi dan statistik
    if pd.api.types.is_numeric_dtype(df[column_name]):
        print(f"Statistik deskriptif:\n{df[column_name].describe()}")
        plt.figure(figsize=(8, 4))
        sns.histplot(df[column_name].dropna(), kde=True, color='teal')
        plt.title(f'Distribusi Kolom: {column_name}')
        plt.xlabel(column_name)
        plt.ylabel('Frekuensi')
        plt.show()
    # Jika kolom kategorikal, tampilkan hitungan nilai
    elif pd.api.types.is_object_dtype(df[column_name]) or pd.api.types.is_categorical_dtype(df[column_name]):
        print(f"Hitungan nilai:\n{df[column_name].value_counts()}")
        if df[column_name].nunique() < 10: # Tampilkan bar plot jika kategori tidak terlalu banyak
            plt.figure(figsize=(8, 4))
            df[column_name].value_counts().plot(kind='bar', color='coral')
            plt.title(f'Hitungan Nilai Kolom: {column_name}')
            plt.xlabel(column_name)
            plt.ylabel('Jumlah')
            plt.xticks(rotation=45, ha='right')
            plt.tight_layout()
            plt.show()


print("\n\n--- Analisis Mendalam per Kolom untuk Tabel-Aset-Tetap.csv ---")
for col in df_aset.columns:
    analyze_column(df_aset, col)

print("\n\n--- Analisis Mendalam per Kolom untuk Tabel-Kebijakan-Fiskal.csv ---")
for col in df_kebijakan.columns:
    analyze_column(df_kebijakan, col)

print("\n\n--- Analisis Mendalam per Kolom untuk Tabel-Transaksi-Keuangan.csv ---")
for col in df_transaksi.columns:
    analyze_column(df_transaksi, col)


# --- Visualisasi Data (Contoh) - Kode sebelumnya ---
# ... (kode visualisasi contoh yang sudah ada) ...


# --- Analisis Komprehensif (Contoh) - Kode sebelumnya ---
# ... (kode analisis korelasi contoh yang sudah ada) ...
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File CSV berhasil dimuat.
#
# --- Analisis Data Tabel-Aset-Tetap.csv ---
# Beberapa baris pertama:
#   aset_id   kategori nilai_perolehan  umur_ekonomis         metode
# 0    A001      Mesin        800,000              15    garis lurus
# 1    A002   Bangunan      2,500,000              30  saldo menurun
# 2    A003  Kendaraan        600,000               7    garis lurus
# 3    A004  Peralatan        450,000              10  saldo menurun
# 4    A005   Komputer        300,000               4    garis lurus
#
# Informasi kolom:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   aset_id          10 non-null     object
#  1   kategori         10 non-null     object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Path ke file CSV di Google Drive Anda
file_aset = '/content/drive/My Drive/Tabel-Aset-Tetap.csv'
file_kebijakan = '/content/drive/My Drive/Tabel-Kebijakan-Fiskal.csv'
file_transaksi = '/content/drive/My Drive/Tabel-Transaksi-Keuangan.csv'

# Memuat data dari file CSV
try:
    df_aset = pd.read_csv(file_aset)
    df_kebijakan = pd.read_csv(file_kebijakan)
    df_transaksi = pd.read_csv(file_transaksi)
    print("File CSV berhasil dimuat.")
except FileNotFoundError:
    print("Pastikan file CSV berada di direktori 'My Drive' di Google Drive Anda.")
    exit()

# --- Eksplorasi Data Awal (Sudah ada) ---
# (Kode untuk eksplorasi data awal)


# --- Analisis Mendalam per Kolom ---
# (Fungsi analyze_column dan loop untuk analisis per kolom)


# --- Visualisasi Data (Grafik Berwarna) ---

print("\n--- Visualisasi Data (Grafik Berwarna) ---")

# Contoh 1: Scatter Plot dengan Warna (Hubungan antara dua kolom numerik)
# Asumsikan df_aset memiliki kolom 'UsiaAset' (numerik) dan 'Nilai' (numerik)
if 'UsiaAset' in df_aset.columns and 'Nilai' in df_aset.columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df_aset, x='UsiaAset', y='Nilai', hue='KategoriAset', palette='viridis') # Gunakan kolom kategorikal untuk warna jika ada
    plt.title('Hubungan antara Usia Aset dan Nilai Aset (dengan Warna Kategori)')
    plt.xlabel('Usia Aset')
    plt.ylabel('Nilai')
    plt.show()
else:
    print("Kolom 'UsiaAset' atau 'Nilai' tidak ditemukan di Tabel-Aset-Tetap.csv untuk Scatter Plot.")


# Contoh 2: Bar Plot dengan Warna (Perbandingan nilai antar kategori)
# Asumsikan df_kebijakan memiliki kolom 'JenisKebijakan' (kategorikal) dan 'Anggaran' (numerik)
if 'JenisKebijakan' in df_kebijakan.columns and 'Anggaran' in df_kebijakan.columns:
    plt.figure(figsize=(12, 6))
    sns.barplot(data=df_kebijakan, x='JenisKebijakan', y='Anggaran', palette='magma')
    plt.title('Rata-rata Anggaran per Jenis Kebijakan')
    plt.xlabel('Jenis Kebijakan')
    plt.ylabel('Rata-rata Anggaran')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
     print("Kolom 'JenisKebijakan' atau 'Anggaran' tidak ditemukan di Tabel-Kebijakan-Fiskal.csv untuk Bar Plot.")


# Contoh 3: Line Plot dengan Warna (Tren data, biasanya seiring waktu)
# Asumsikan df_kebijakan memiliki kolom 'Tahun' (numerik/tanggal) dan 'Anggaran' (numerik)
if 'Tahun' in df_kebijakan.columns and 'Anggaran' in df_kebijakan.columns:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_kebijakan, x='Tahun', y='Anggaran', marker='o', color='lightcoral')
    plt.title('Tren Anggaran Kebijakan Fiskal per Tahun')
    plt.xlabel('Tahun')
    plt.ylabel('Anggaran')
    plt.grid(True)
    plt.show()
else:
    print("Kolom 'Tahun' atau 'Anggaran' tidak ditemukan di Tabel-Kebijakan-Fiskal.csv untuk Line Plot.")


# Contoh 4: Box Plot dengan Warna (Distribusi per kategori)
# Asumsikan df_transaksi memiliki kolom 'Jenis Transaksi' (kategorikal) dan 'Jumlah' (numerik)
if 'Jenis Transaksi' in df_transaksi.columns and 'Jumlah' in df_transaksi.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df_transaksi, x='Jenis Transaksi', y='Jumlah', palette='viridis')
    plt.title('Distribusi Jumlah Transaksi per Jenis')
    plt.xlabel('Jenis Transaksi')
    plt.ylabel('Jumlah')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
else:
     print("Kolom 'Jenis Transaksi' atau 'Jumlah' tidak ditemukan di Tabel-Transaksi-Keuangan.csv untuk Box Plot.")


# Contoh 5: Heatmap (Visualisasi korelasi antar kolom numerik)
# Asumsikan df_transaksi memiliki beberapa kolom numerik
if df_transaksi.select_dtypes(include=np.number).shape[1] > 1:
    print("\n--- Heatmap Korelasi dalam Tabel-Transaksi-Keuangan.csv ---")
    correlation_matrix = df_transaksi.select_dtypes(include=np.number).corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Heatmap Korelasi Tabel-Transaksi-Keuangan.csv')
    plt.show()
else:
    print("Tidak cukup kolom numerik di Tabel-Transaksi-Keuangan.csv untuk Heatmap Korelasi.")


# --- Analisis Komprehensif (Contoh) ---
# (Kode untuk analisis komprehensif lainnya, seperti korelasi)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File CSV berhasil dimuat.
#
# --- Visualisasi Data (Grafik Berwarna) ---
# Kolom 'UsiaAset' atau 'Nilai' tidak ditemukan di Tabel-Aset-Tetap.csv untuk Scatter Plot.
# Kolom 'JenisKebijakan' atau 'Anggaran' tidak ditemukan di Tabel-Kebijakan-Fiskal.csv untuk Bar Plot.
# Kolom 'Tahun' atau 'Anggaran' tidak ditemukan di Tabel-Kebijakan-Fiskal.csv untuk Line Plot.
# Kolom 'Jenis Transaksi' atau 'Jumlah' tidak ditemukan di Tabel-Transaksi-Keuangan.csv untuk Box Plot.
#
# --- Heatmap Korelasi dalam Tabel-Transaksi-Keuangan.csv ---

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Path ke file CSV di Google Drive Anda
file_aset = '/content/drive/My Drive/Tabel-Aset-Tetap.csv'

# Memuat data dari file CSV
try:
    df_aset = pd.read_csv(file_aset)
    print("File CSV Tabel-Aset-Tetap.csv berhasil dimuat.")
except FileNotFoundError:
    print("Pastikan file CSV berada di direktori 'My Drive' di Google Drive Anda.")
    exit()

# --- Pengelompokan Berdasarkan metode ---

# Asumsikan ada kolom 'metode' di df_aset
if 'metode' in df_aset.columns:
    print("\n--- Analisis Berdasarkan metode ---")

    # Mengelompokkan DataFrame berdasarkan kolom 'metode'
    grouped_by_metode = df_aset.groupby('metode')

    # Menampilkan informasi untuk setiap kelompok
    for metode, group in grouped_by_metode:
        print(f"\nMetode: {metode}")
        print("Jumlah aset:", len(group))
        # Anda bisa menambahkan analisis lebih lanjut di sini untuk setiap kelompok
        # Contoh: Statistik deskriptif untuk kolom numerik di kelompok ini
        print("Statistik deskriptif (untuk kolom numerik):")
        print(group.describe())

        # Contoh: Menampilkan beberapa baris pertama dari kelompok ini
        print("\nBeberapa baris pertama dari kelompok ini:")
        print(group.head())

else:
    print("\nKolom 'metode' tidak ditemukan di Tabel-Aset-Tetap.csv.")
    print("Harap pastikan nama kolom metode penyusutan di file Anda sudah benar.")

# Anda dapat menambahkan visualisasi per kelompok di sini jika diperlukan
# Misalnya, histogram 'Nilai' untuk setiap metode penyusutan.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File CSV Tabel-Aset-Tetap.csv berhasil dimuat.
#
# --- Analisis Berdasarkan metode ---
#
# Metode: garis lurus
# Jumlah aset: 5
# Statistik deskriptif (untuk kolom numerik):
#        umur_ekonomis
# count       5.000000
# mean       13.200000
# std        10.232302
# min         4.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max        30.000000
#
# Beberapa baris pertama dari kelompok ini:
#   aset_id   kategori nilai_perolehan  umur_ekonomis       metode
# 0    A001      Mesin        800,000              15  garis lurus
# 2    A003  Kendaraan        600,000               7  garis lurus
# 4    A005   Komputer        300,000               4  garis lurus
# 6    A007   Bangunan      2,550,000              30  garis lurus
# 8    A009  Peralatan        500,000              10  garis lurus
#
# Metode: saldo menurun
# ...
